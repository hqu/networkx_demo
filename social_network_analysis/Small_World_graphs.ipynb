# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G_er_low = nx.Graph()
G_er_med = nx.Graph()
G_er_high = nx.Graph()
G_ws_large = nx.Graph()
G_ws_small = nx.Graph()
G_ws_ultrasmall = nx.Graph()

# %%
G_er_low = nx.erdos_renyi_graph(20, .1)

# %%
fig = plt.figure(figsize=(5,4))
nx.draw_spring(G_er_low, node_size=20, with_labels = True)

# %%
G_er_med = nx.erdos_renyi_graph(20, .4)

# %%
G_er_50_nodes = nx.erdos_renyi_graph(50, .1)

# %%
fig = plt.figure(figsize=(6,7))
nx.draw_spring(G_er_50_nodes, node_size=20, with_labels = True)

# %%
print(nx.average_shortest_path_length(G_er_50_nodes))
# Out:
# 2.6228571428571428

# %%
fig = plt.figure(figsize=(5,4))
nx.draw_spring(G_er_med, node_size=20, with_labels = True)

# %%
print(nx.average_shortest_path_length(G_er_med))
# Out:
# 1.568421052631579

# %%
G_er_high = nx.erdos_renyi_graph(20, .8)

# %%
fig = plt.figure(figsize=(5,4))
nx.draw_spring(G_er_high, node_size=20, with_labels = True)

# %%
print(nx.average_shortest_path_length(G_er_high))
# Out:
# 1.1368421052631579

# %%
G_ws_0 = nx.watts_strogatz_graph(100, 2, 0)

# %%
fig = plt.figure(figsize=(8,6))
nx.draw_circular(G_ws_0, node_size=20)

# %%
print(nx.average_shortest_path_length(G_ws_0))
# Out:
# 25.252525252525253

# %%
G_ws_large = nx.connected_watts_strogatz_graph(100, 2, .1)

# %%
fig = plt.figure(figsize=(8,6))
nx.draw_circular(G_ws_large, node_size=20)

# %%
print(nx.average_shortest_path_length(G_ws_large))
# Out:
# 21.853131313131314

# %%
G_ws_small = nx.connected_watts_strogatz_graph(100, 2, .5)

# %%
fig = plt.figure(figsize=(8,6))
nx.draw_circular(G_ws_small, node_size=20)

# %%
print(nx.average_shortest_path_length(G_ws_small))
# Out:
# 15.494949494949495

# %%
G_ws_ultrasmall = nx.connected_watts_strogatz_graph(100, 2, .8)

# %%
fig = plt.figure(figsize=(8,6))
nx.draw_circular(G_ws_ultrasmall, node_size=20)

# %%
print(nx.average_shortest_path_length(G_ws_ultrasmall))
# Out:
# 11.916565656565657
